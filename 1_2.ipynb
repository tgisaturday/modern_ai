# %% [markdown]
# ## 구글 Colab 시작하기

# %%
import sys
print(sys.version)

# %%
import numpy as np
import torch

print(np.__version__)
print(torch.__version__)

# %%
# !pip install tqdm

# %%
import torch
print(torch.cuda.is_available())

# %% [markdown]
# ## [프로그램 1-1] Colab에서 첫 번째 프로그램 작성하기

# %%
import torch
import numpy as np

# NumPy 연산 확인
a = np.array([1, 2, 3])
print(a * 2)

# PyTorch 텐서 연산 확인
x = torch.tensor([1.0, 2.0, 3.0])
y = x * 2
print(y)
